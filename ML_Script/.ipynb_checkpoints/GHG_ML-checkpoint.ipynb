# %%
# Importing the libraries
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import requests
import json

# %%
# CSV Path
csv_path = os.path.join("..","Data", "Cleaned", "GHGvsGDP.csv")

# Reading CSV as DF
ghg_gdp_df = pd.read_csv(csv_path)
ghg_gdp_df.tail(5)
# Out:
#        Country    Year  \
# 4318     Yemen  2012.0
# 4319    Zambia  2012.0
# 4320  Zimbabwe  2012.0
# 4321       NaN     NaN
# 4322       NaN     NaN
#
#       Total GHG Emissions Including Land-Use Change and Forestry (MtCO_e_)  \
# 4318                                              29.84
# 4319                                             119.81
# 4320                                              62.93
# 4321                                                NaN
# 4322                                                NaN
#
#      GDP-USD (Million US$ (2005))  Population (People) GHG per Capita  \
# 4318                        17392           23852409.0           1.25
# 4319                        14354           14075099.0           8.51
# 4320                         6437           13724317.0           4.59
# 4321                          NaN                  NaN            NaN
# 4322                          NaN                  NaN            NaN
#
#      GDP per Capita
# 4318         729.15
# 4319        1019.82
# 4320         469.02
# 4321            NaN
# 4322            NaN

# %%
# Dropping NaN
cleaned_df = ghg_gdp_df.dropna()

# Dropping Aggragate World Data
cleaned_df = cleaned_df[(cleaned_df['Country']!="World")]
cleaned_df = cleaned_df[(cleaned_df['Country']!="European Union")]
cleaned_df
# Out:
#                 Country    Year  \
# 0           Afghanistan  1990.0
# 1               Albania  1990.0
# 2               Algeria  1990.0
# 3                Angola  1990.0
# 4     Antigua & Barbuda  1990.0
# ...                 ...     ...
# 4315          Venezuela  2012.0
# 4316            Vietnam  2012.0
# 4318              Yemen  2012.0
# 4319             Zambia  2012.0
# 4320           Zimbabwe  2012.0
#
#       Total GHG Emissions Including Land-Use Change and Forestry (MtCO_e_)  \
# 0                                                 15.96
# 1                                                 12.18
# 2                                                 94.07
# 3                                                105.02
# 4                                                  0.40
# ...                                                 ...
# 4315                                             396.74
# 4316                                             251.18
# 4318                                              29.84
# 4319                                             119.81
# 4320                                              62.93
#
#      GDP-USD (Million US$ (2005))  Population (People) GHG per Capita  \
# 0                            3622           11731193.0           1.36
# 1                            5620            3286542.0           3.71
# 2                           66766           26239708.0           3.59
# 3                           15989           10333844.0          10.16
# 4                             599              61906.0           6.52
# ...                           ...                  ...            ...
# 4315                       192071           29954782.0          13.24
# 4316                        87531           88772900.0           2.83
# 4318                        17392           23852409.0           1.25
# 4319                        14354           14075099.0           8.51
# 4320                         6437           13724317.0           4.59
#
#      GDP per Capita
# 0            308.75
# 1           1710.00
# 2           2544.46
# 3           1547.25
# 4           9675.96
# ...             ...
# 4315        6412.03
# 4316         986.01
# 4318         729.15
# 4319        1019.82
# 4320         469.02
#
# [4296 rows x 7 columns]

# %%
# Data for Simple ML
simple_ml_df = cleaned_df[["GDP per Capita", "GHG per Capita"]].copy()

#X and Y values for Linear Regression Model
X = simple_ml_df.iloc[:, :-1].values
y = simple_ml_df.iloc[:, 1].values

simple_ml_df.tail(5)
# Out:
#      GDP per Capita GHG per Capita
# 4315        6412.03          13.24
# 4316         986.01           2.83
# 4318         729.15           1.25
# 4319        1019.82           8.51
# 4320         469.02           4.59

# %%
# Imports from SciKit Learn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/2, random_state = 0)

# %%
# Fitting Simple Linear Regression to the Training set
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Predicting the Test set results
y_pred = regressor.predict(X_test)

# %%
# Saving model to disk
pickle.dump(regressor, open('ghg_linear_model.pkl','wb'))

# %%
# Loading model to compare the results
model = pickle.load( open('ghg_linear_model.pkl','rb'))
print(model.predict([[1080]]))
# Out:
# [5.8858669]
